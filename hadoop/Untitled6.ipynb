# %%
import re
import requests
from bs4 import BeautifulSoup

url = 'http://www.weather.go.kr/weather/observation/currentweather.jsp?type=t99&mode=0&stn=0&reg=100&auto_man=m&tm=2021.04.27.17:00&dtm=-1'
res = requests.get(url)
res.raise_for_status()

soup = BeautifulSoup(res.text, 'lxml')

table = soup.find("table", attrs = {"class" : "table_develop3"})

# %%
table1 = table.find_all("tr")
# 이명령어 자체를 시행하면 리스트 형태로 짤린다 생각하자.
#무조건 for문 돌려야하네요... find all 다음에

# %%
for i in table1 :
# Out:
#  <td>20 이상</td>
#  <td> </td>
#  <td> </td>
#  <td>15.5</td>
#  <td>8.7</td>
#  <td>16.8</td>
#  <td>0.0</td>
#  <td> </td>
#  <td>64</td>
#  <td>북동</td>
#  <td><script>writeWindSpeed('0.7', false, '', '', 1);</script></td>
#  <td>1013.3</td>
#  </tr>,
#  <tr>
#  <td><a href="/weather/observation/currentweather.jsp?tm=2021.4.27.16:00&amp;type=t99&amp;mode=0&amp;reg=100&amp;auto_man=m&amp;stn=119">수원</a></td>
#  <td>흐림</td>
#  <td>19.2</td>
#  <td>10</td>
#  <td>10</td>
#  <td>18.6</td>
#  <td>7.9</td>
#  <td>19.0</td>
#  <td>0.0</td>
#  <td> </td>
#  <td>50</td>
#  <td>서남서</td>
#  <td><script>writeWindSpeed('2.8', false, '', '', 1);</script></td>
#  <td>1016.1</td>
#  </tr>,
#  <tr>
#  <td><a href="/weather/observation/currentweather.jsp?tm=2021.4.27.16:00&amp;type=t99&amp;mode=0&amp;reg=100&amp;auto_man=m&amp;stn=254">순창군</a></td>
#  <td> </td>
#  <td>18.7</td>
#  <td> </td>
#  <td> </td>
#  <td>21.4</td>
#  <td>3.0</td>
#  <td>20.0</td>
#  <td> </td>
#  <td> </td>
#  <td>30</td>
# ...
