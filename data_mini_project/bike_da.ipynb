# %%
import pandas as pd
import numpy

x1_name = "log.xlsx"
api_name = "log_api.csv"

x1 = pd.read_excel("log.xlsx")
api = pd.read_csv("log_api.csv",encoding = 'cp949')

# %%
x1
# Out:
#         대여소 그룹                대여소 명  반납 일자 / 월  반납 건수
# 0       그룹명 없음              대여소명 없음 2017-01-01     10
# 1          광진구  500. 어린이대공원역 3번출구 앞 2017-01-01     12
# 2          광진구         501. 광진구의회 앞 2017-01-01     10
# 3          광진구   502. 뚝섬유원지역 1번출구 앞 2017-01-01     13
# 4          광진구     503. 더샵스타시티 C동 앞 2017-01-01      8
# ...        ...                  ...        ...    ...
# 245441     중랑구  1442. (구)신한은행 중랑교지점 2017-12-31      1
# 245442     중랑구          1445. 용마지구대 2017-12-31      0
# 245443     중랑구      1446. 중랑전화국 교차로 2017-12-31      2
# 245444     중랑구       1447. 면목역 3번출구 2017-12-31      2
# 245445     중랑구       1448. 코스트코 상봉점 2017-12-31      8
#
# [245446 rows x 4 columns]

# %%
api
# Out:
#       대여소\n번호          보관소(대여소)명 소재지(위치)           Unnamed: 3 Unnamed: 4  \
# 0         NaN                NaN     NaN                  NaN        NaN
# 1         NaN                NaN     자치구                 상세주소         위도
# 2         NaN                NaN     NaN                  NaN        NaN
# 3         NaN                NaN     NaN                  NaN        NaN
# 4       301.0        경복궁역 7번출구 앞     종로구  서울특별시 종로구 사직로 지하130  37.575794
# ...       ...                ...     ...                  ...        ...
# 2156   1089.0  고덕 래미안힐스테이트(201동)     강동구              고덕동 675  37.560600
# 2157   1090.0        상일동역 2번출구 앞     강동구              고덕로 333  37.556789
# 2158      NaN                NaN     NaN                  NaN        NaN
# 2159      NaN                NaN     NaN                  NaN        NaN
# 2160      NaN                NaN     NaN                  NaN        NaN
#
#       Unnamed: 5      설치\n시기    설치형태 Unnamed: 8 운영\n방식
# 0            NaN         NaN     LCD         QR    NaN
# 1             경도         NaN     NaN        NaN    NaN
# 2            NaN         NaN  거치\n대수     거치\n대수    NaN
# 3            NaN         NaN     NaN        NaN    NaN
# 4     126.971451  2015-10-07      16        NaN    LCD
# ...          ...         ...     ...        ...    ...
# 2156  127.146698  2020-01-13     NaN         10     QR
# 2157  127.166145  2020-01-13     NaN         10     QR
# 2158         NaN         NaN     NaN        NaN    NaN
# 2159         NaN         NaN     NaN        NaN    NaN
# 2160         NaN         NaN     NaN        NaN    NaN
#
# [2161 rows x 10 columns]

# %%
x1.columns = ['x_소재지','x_대여소명1','x_반납일자','x_반납건수']
x1
# Out:
#          x_소재지              x_대여소명1     x_반납일자  x_반납건수
# 0       그룹명 없음              대여소명 없음 2017-01-01      10
# 1          광진구  500. 어린이대공원역 3번출구 앞 2017-01-01      12
# 2          광진구         501. 광진구의회 앞 2017-01-01      10
# 3          광진구   502. 뚝섬유원지역 1번출구 앞 2017-01-01      13
# 4          광진구     503. 더샵스타시티 C동 앞 2017-01-01       8
# ...        ...                  ...        ...     ...
# 245441     중랑구  1442. (구)신한은행 중랑교지점 2017-12-31       1
# 245442     중랑구          1445. 용마지구대 2017-12-31       0
# 245443     중랑구      1446. 중랑전화국 교차로 2017-12-31       2
# 245444     중랑구       1447. 면목역 3번출구 2017-12-31       2
# 245445     중랑구       1448. 코스트코 상봉점 2017-12-31       8
#
# [245446 rows x 4 columns]

# %%
api.columns = ['a_대여소번호','a_대여소명','a_소재지','a_상세주소','a_위도','a_경도','a_설치시기','a_설치형태LCD','a_설치형태QR','a_운영방식']
api
# Out:
#       a_대여소번호             a_대여소명 a_소재지               a_상세주소       a_위도  \
# 0         NaN                NaN   NaN                  NaN        NaN
# 1         NaN                NaN   자치구                 상세주소         위도
# 2         NaN                NaN   NaN                  NaN        NaN
# 3         NaN                NaN   NaN                  NaN        NaN
# 4       301.0        경복궁역 7번출구 앞   종로구  서울특별시 종로구 사직로 지하130  37.575794
# ...       ...                ...   ...                  ...        ...
# 2156   1089.0  고덕 래미안힐스테이트(201동)   강동구              고덕동 675  37.560600
# 2157   1090.0        상일동역 2번출구 앞   강동구              고덕로 333  37.556789
# 2158      NaN                NaN   NaN                  NaN        NaN
# 2159      NaN                NaN   NaN                  NaN        NaN
# 2160      NaN                NaN   NaN                  NaN        NaN
#
#             a_경도      a_설치시기 a_설치형태LCD a_설치형태QR a_운영방식
# 0            NaN         NaN       LCD       QR    NaN
# 1             경도         NaN       NaN      NaN    NaN
# 2            NaN         NaN    거치\n대수   거치\n대수    NaN
# 3            NaN         NaN       NaN      NaN    NaN
# 4     126.971451  2015-10-07        16      NaN    LCD
# ...          ...         ...       ...      ...    ...
# 2156  127.146698  2020-01-13       NaN       10     QR
# 2157  127.166145  2020-01-13       NaN       10     QR
# 2158         NaN         NaN       NaN      NaN    NaN
# 2159         NaN         NaN       NaN      NaN    NaN
# 2160         NaN         NaN       NaN      NaN    NaN
#
# [2161 rows x 10 columns]

# %%
# x1.loc['x_대여소명1'['2333 양재역 3번출구 주변']] = '2333. 양재역 3번출구 주변'
x1.loc[(x1.x_대여소명1 == '2333 양재역 3번출구 주변'), 'x_대여소명1'] = '2333. 양재역 3번출구 주변'

# %%
import pandas as pd
import numpy
x1["x_대여소번호"] = ""
x1["x_대여소명"] = ""
x1
# Out:
#          x_소재지              x_대여소명1     x_반납일자  x_반납건수 x_대여소번호 x_대여소명
# 0       그룹명 없음              대여소명 없음 2017-01-01      10
# 1          광진구  500. 어린이대공원역 3번출구 앞 2017-01-01      12
# 2          광진구         501. 광진구의회 앞 2017-01-01      10
# 3          광진구   502. 뚝섬유원지역 1번출구 앞 2017-01-01      13
# 4          광진구     503. 더샵스타시티 C동 앞 2017-01-01       8
# ...        ...                  ...        ...     ...     ...    ...
# 245441     중랑구  1442. (구)신한은행 중랑교지점 2017-12-31       1
# 245442     중랑구          1445. 용마지구대 2017-12-31       0
# 245443     중랑구      1446. 중랑전화국 교차로 2017-12-31       2
# 245444     중랑구       1447. 면목역 3번출구 2017-12-31       2
# 245445     중랑구       1448. 코스트코 상봉점 2017-12-31       8
#
# [245446 rows x 6 columns]

# %%
x1_split = x1["x_대여소명1"].str.split(".")
x1["x_대여소번호"] = x1_split.str.get(0)
x1["x_대여소명"] = x1_split.str.get(1)
x1
# Out:
#          x_소재지              x_대여소명1     x_반납일자  x_반납건수  x_대여소번호  \
# 0       그룹명 없음              대여소명 없음 2017-01-01      10  대여소명 없음
# 1          광진구  500. 어린이대공원역 3번출구 앞 2017-01-01      12      500
# 2          광진구         501. 광진구의회 앞 2017-01-01      10      501
# 3          광진구   502. 뚝섬유원지역 1번출구 앞 2017-01-01      13      502
# 4          광진구     503. 더샵스타시티 C동 앞 2017-01-01       8      503
# ...        ...                  ...        ...     ...      ...
# 245441     중랑구  1442. (구)신한은행 중랑교지점 2017-12-31       1     1442
# 245442     중랑구          1445. 용마지구대 2017-12-31       0     1445
# 245443     중랑구      1446. 중랑전화국 교차로 2017-12-31       2     1446
# 245444     중랑구       1447. 면목역 3번출구 2017-12-31       2     1447
# 245445     중랑구       1448. 코스트코 상봉점 2017-12-31       8     1448
#
#                  x_대여소명
# 0                   NaN
# 1        어린이대공원역 3번출구 앞
# 2               광진구의회 앞
# 3         뚝섬유원지역 1번출구 앞
# 4           더샵스타시티 C동 앞
# ...                 ...
# 245441    (구)신한은행 중랑교지점
# 245442            용마지구대
# 245443        중랑전화국 교차로
# 245444         면목역 3번출구
# 245445         코스트코 상봉점
#
# [245446 rows x 6 columns]

# %%
x1 = x1[x1.x_대여소번호 != '대여소명 없음']
x1 = x1[x1.x_대여소번호 != '중랑정비팀test 1005']
x1.tail()
# Out:
#        x_소재지              x_대여소명1     x_반납일자  x_반납건수 x_대여소번호          x_대여소명
# 245441   중랑구  1442. (구)신한은행 중랑교지점 2017-12-31       1    1442   (구)신한은행 중랑교지점
# 245442   중랑구          1445. 용마지구대 2017-12-31       0    1445           용마지구대
# 245443   중랑구      1446. 중랑전화국 교차로 2017-12-31       2    1446       중랑전화국 교차로
# 245444   중랑구       1447. 면목역 3번출구 2017-12-31       2    1447        면목역 3번출구
# 245445   중랑구       1448. 코스트코 상봉점 2017-12-31       8    1448        코스트코 상봉점

# %%
# x1[x1['x_대여소명1'] == '2333 양재역 3번출구 주변','x_대여소번호'] = '2333. 양재역 3번출구 주변'

# %%
import numpy as np
x1 = x1.astype({'x_대여소번호':np.float})

# %%
x1.dtypes
x1
# Out:
#        x_소재지              x_대여소명1     x_반납일자  x_반납건수  x_대여소번호           x_대여소명
# 1        광진구  500. 어린이대공원역 3번출구 앞 2017-01-01      12    500.0   어린이대공원역 3번출구 앞
# 2        광진구         501. 광진구의회 앞 2017-01-01      10    501.0          광진구의회 앞
# 3        광진구   502. 뚝섬유원지역 1번출구 앞 2017-01-01      13    502.0    뚝섬유원지역 1번출구 앞
# 4        광진구     503. 더샵스타시티 C동 앞 2017-01-01       8    503.0      더샵스타시티 C동 앞
# 5        광진구       504. 신자초교입구교차로 2017-01-01      13    504.0        신자초교입구교차로
# ...      ...                  ...        ...     ...      ...              ...
# 245441   중랑구  1442. (구)신한은행 중랑교지점 2017-12-31       1   1442.0    (구)신한은행 중랑교지점
# 245442   중랑구          1445. 용마지구대 2017-12-31       0   1445.0            용마지구대
# 245443   중랑구      1446. 중랑전화국 교차로 2017-12-31       2   1446.0        중랑전화국 교차로
# 245444   중랑구       1447. 면목역 3번출구 2017-12-31       2   1447.0         면목역 3번출구
# 245445   중랑구       1448. 코스트코 상봉점 2017-12-31       8   1448.0         코스트코 상봉점
#
# [244598 rows x 6 columns]

# %%
x1.drop(['x_대여소명1'], axis = 1)
# Out:
#        x_소재지     x_반납일자  x_반납건수  x_대여소번호           x_대여소명
# 1        광진구 2017-01-01      12    500.0   어린이대공원역 3번출구 앞
# 2        광진구 2017-01-01      10    501.0          광진구의회 앞
# 3        광진구 2017-01-01      13    502.0    뚝섬유원지역 1번출구 앞
# 4        광진구 2017-01-01       8    503.0      더샵스타시티 C동 앞
# 5        광진구 2017-01-01      13    504.0        신자초교입구교차로
# ...      ...        ...     ...      ...              ...
# 245441   중랑구 2017-12-31       1   1442.0    (구)신한은행 중랑교지점
# 245442   중랑구 2017-12-31       0   1445.0            용마지구대
# 245443   중랑구 2017-12-31       2   1446.0        중랑전화국 교차로
# 245444   중랑구 2017-12-31       2   1447.0         면목역 3번출구
# 245445   중랑구 2017-12-31       8   1448.0         코스트코 상봉점
#
# [244598 rows x 5 columns]

# %%
merge_bike = pd.merge(x1,api, how = 'left', left_on ='x_대여소번호', right_on = 'a_대여소번호')
mb = merge_bike
mb
# Out:
#        x_소재지              x_대여소명1     x_반납일자  x_반납건수  x_대여소번호  \
# 0        광진구  500. 어린이대공원역 3번출구 앞 2017-01-01      12    500.0
# 1        광진구         501. 광진구의회 앞 2017-01-01      10    501.0
# 2        광진구   502. 뚝섬유원지역 1번출구 앞 2017-01-01      13    502.0
# 3        광진구     503. 더샵스타시티 C동 앞 2017-01-01       8    503.0
# 4        광진구       504. 신자초교입구교차로 2017-01-01      13    504.0
# ...      ...                  ...        ...     ...      ...
# 244927   중랑구  1442. (구)신한은행 중랑교지점 2017-12-31       1   1442.0
# 244928   중랑구          1445. 용마지구대 2017-12-31       0   1445.0
# 244929   중랑구      1446. 중랑전화국 교차로 2017-12-31       2   1446.0
# 244930   중랑구       1447. 면목역 3번출구 2017-12-31       2   1447.0
# 244931   중랑구       1448. 코스트코 상봉점 2017-12-31       8   1448.0
#
#                  x_대여소명  a_대여소번호          a_대여소명 a_소재지               a_상세주소  \
# 0        어린이대공원역 3번출구 앞    500.0  어린이대공원역 3번출구 앞   광진구  서울특별시 광진구 능동로 지하210
# 1               광진구의회 앞    501.0         광진구의회 앞   광진구     서울특별시 광진구 능동로 76
# 2         뚝섬유원지역 1번출구 앞    502.0   뚝섬유원지역 1번출구 앞   광진구     서울특별시 광진구 능동로 10
# 3           더샵스타시티 C동 앞      NaN             NaN   NaN                  NaN
# 4             신자초교입구교차로      NaN             NaN   NaN                  NaN
# ...                 ...      ...             ...   ...                  ...
# 244927    (구)신한은행 중랑교지점   1442.0   (구)신한은행 중랑교지점   중랑구       서울특별시 중화동 50-8
# 244928            용마지구대   1445.0           용마지구대   중랑구      서울특별시 면목동 197-5
# 244929        중랑전화국 교차로   1446.0       중랑전화국 교차로   중랑구  서울특별시 중랑구 면목동 282-8
# 244930         면목역 3번출구   1447.0        면목역 3번출구   중랑구      서울특별시 면목동 120-2
# 244931         코스트코 상봉점   1448.0        코스트코 상봉점   중랑구      서울특별시 상봉동 160-3
#
#              a_위도        a_경도      a_설치시기 a_설치형태LCD a_설치형태QR a_운영방식
# 0       37.547070  127.074272  2015-10-07        10      NaN    LCD
# 1       37.537308  127.070351  2015-10-07        30      NaN    LCD
# 2       37.531860  127.067192  2015-10-07        27      NaN    LCD
# 3             NaN         NaN         NaN       NaN      NaN    NaN
# 4             NaN         NaN         NaN       NaN      NaN    NaN
# ...           ...         ...         ...       ...      ...    ...
# 244927  37.598591  127.079819  2017-11-01         8      NaN    LCD
# 244928  37.579941  127.079399  2017-11-01        10      NaN    LCD
# 244929  37.591301  127.080330  2017-11-01        10      NaN    LCD
# 244930  37.588902  127.087280  2017-11-01        15      NaN    LCD
# 244931  37.597321  127.089798  2017-11-01        15      NaN    LCD
#
# [244932 rows x 16 columns]

# %% [markdown]
# ## 강남구

# %%
# import re
# # m_seocho = r'[서초]+'
# # find_seocho = re.findall(m_seocho, mb.x_소재지)
# find_seocho = mb.x_소재지.findall(r'[서초]+')
# print(find_seocho)

# %%
find_gangnam = mb[mb['x_소재지'].str.contains('강남구')]
fg = find_gangnam
fg
# Out:
#        x_소재지              x_대여소명1     x_반납일자  x_반납건수  x_대여소번호          x_대여소명  \
# 76725    강남구   2309. 청담역(우리들병원 앞) 2017-06-15       6   2309.0    청담역(우리들병원 앞)
# 76726    강남구        2331. 동영문화센터앞 2017-06-15       2   2331.0         동영문화센터앞
# 76727    강남구  2337. 대모산입구역 2번출구 앞 2017-06-15       7   2337.0   대모산입구역 2번출구 앞
# 77339    강남구   2309. 청담역(우리들병원 앞) 2017-06-16      16   2309.0    청담역(우리들병원 앞)
# 77340    강남구         2330. 스타벅스 앞 2017-06-16       1   2330.0          스타벅스 앞
# ...      ...                  ...        ...     ...      ...             ...
# 244053   강남구       2370. 한티역 3번출구 2017-12-31       1   2370.0        한티역 3번출구
# 244054   강남구      2371. 한국우편사업진흥원 2017-12-31       0   2371.0       한국우편사업진흥원
# 244055   강남구        2372. 대치역 사거리 2017-12-31       4   2372.0         대치역 사거리
# 244056   강남구       2373. 개포동역 사거리 2017-12-31       2   2373.0        개포동역 사거리
# 244057   강남구     2375. 수서역 1번출구 앞 2017-12-31       1   2375.0      수서역 1번출구 앞
#
#         a_대여소번호         a_대여소명 a_소재지               a_상세주소       a_위도  \
# 76725    2309.0   청담역(우리들병원 앞)   강남구    서울특별시 강남구 학동로 443  37.518902
# 76726    2331.0        동영문화센터앞   강남구    서울특별시 강남구 언주로 337  37.498051
# 76727    2337.0  대모산입구역 2번출구 앞   강남구   서울특별시 강남구 영동대로 101  37.492077
# 77339    2309.0   청담역(우리들병원 앞)   강남구    서울특별시 강남구 학동로 443  37.518902
# 77340    2330.0         스타벅스 앞   강남구    서울특별시 강남구 도곡로 183  37.492199
# ...         ...            ...   ...                  ...        ...
# 244053   2370.0       한티역 3번출구   강남구   서울특별시 강남구 대치동 1026  37.496552
# 244054   2371.0      한국우편사업진흥원   강남구    서울특별시 강남구 언주로 651  37.514748
# 244055   2372.0        대치역 사거리   강남구   서울특별시 강남구 삼성로 156   37.494499
# 244056   2373.0       개포동역 사거리   강남구  서울특별시 강남구 개포동 181-3  37.489277
# 244057   2375.0     수서역 1번출구 앞   강남구    서울특별시 강남구 수서동 728  37.487350
#
#               a_경도      a_설치시기 a_설치형태LCD a_설치형태QR a_운영방식
# 76725   127.049385  2017-06-13        10      NaN    LCD
# 76726   127.044601  2017-06-13        20      NaN    LCD
# 76727   127.071976  2017-06-13        15      NaN    LCD
# 77339   127.049385  2017-06-13        10      NaN    LCD
# 77340   127.039459  2017-06-13        10      NaN    LCD
# ...            ...         ...       ...      ...    ...
# 244053  127.054298  2017-11-01        20      NaN    LCD
# 244054  127.035133  2017-11-01        10      NaN    LCD
# 244055  127.063797  2017-11-01        10      NaN    LCD
# 244056  127.065575  2017-11-01        20      NaN    LCD
# 244057  127.100998  2017-11-01        10      NaN    LCD
#
# [9259 rows x 16 columns]

# %%
fg = fg.drop(['x_대여소명1','x_대여소명','a_소재지','a_설치시기','a_설치형태LCD','a_운영방식','a_설치형태QR'], axis=1)
fg
# Out:
#        x_소재지     x_반납일자  x_반납건수  x_대여소번호  a_대여소번호         a_대여소명  \
# 76725    강남구 2017-06-15       6   2309.0   2309.0   청담역(우리들병원 앞)
# 76726    강남구 2017-06-15       2   2331.0   2331.0        동영문화센터앞
# 76727    강남구 2017-06-15       7   2337.0   2337.0  대모산입구역 2번출구 앞
# 77339    강남구 2017-06-16      16   2309.0   2309.0   청담역(우리들병원 앞)
# 77340    강남구 2017-06-16       1   2330.0   2330.0         스타벅스 앞
# ...      ...        ...     ...      ...      ...            ...
# 244053   강남구 2017-12-31       1   2370.0   2370.0       한티역 3번출구
# 244054   강남구 2017-12-31       0   2371.0   2371.0      한국우편사업진흥원
# 244055   강남구 2017-12-31       4   2372.0   2372.0        대치역 사거리
# 244056   강남구 2017-12-31       2   2373.0   2373.0       개포동역 사거리
# 244057   강남구 2017-12-31       1   2375.0   2375.0     수서역 1번출구 앞
#
#                      a_상세주소       a_위도        a_경도
# 76725     서울특별시 강남구 학동로 443  37.518902  127.049385
# 76726     서울특별시 강남구 언주로 337  37.498051  127.044601
# 76727    서울특별시 강남구 영동대로 101  37.492077  127.071976
# 77339     서울특별시 강남구 학동로 443  37.518902  127.049385
# 77340     서울특별시 강남구 도곡로 183  37.492199  127.039459
# ...                     ...        ...         ...
# 244053   서울특별시 강남구 대치동 1026  37.496552  127.054298
# 244054    서울특별시 강남구 언주로 651  37.514748  127.035133
# 244055   서울특별시 강남구 삼성로 156   37.494499  127.063797
# 244056  서울특별시 강남구 개포동 181-3  37.489277  127.065575
# 244057    서울특별시 강남구 수서동 728  37.487350  127.100998
#
# [9259 rows x 9 columns]

# %%
fg.to_excel('C:/Users/Admin/Desktop/success/Python/export_sample.xlsx',sheet_name = 'find_gandnam')

# %% [markdown]
#  ## 시각화하기

# %%
import folium
import pandas as pd
geo_json = 'https://raw.githubusercontent.com/southkorea/seoul-maps/master/kostat/2013/json/seoul_municipalities_geo_simple.json'
rent = pd.read_csv('result.csv')
rent


m = folium.Map(
location=[37.49219733873561, 127.06587727049637], zoom_start=15)


folium.Choropleth(
    geo_data= geo_json,
    name ='choropleth',
    data = rent,
    columns = ['소재지','반납건수'],
    key_on = 'feature.properties.name',
    fill_color='YlGn',
    fill_opacity=0.7,
    line_opacity=0.2,
).add_to(m)
    # location=[37.49219733873561, 127.06587727049637], zoom_start=15)
# folium.Circle([37.518902,127.049385], radius = 200, color = '#ABF200', fill = True, fill_color='#ABF200').add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_8c8a143b88af473c963bf84f4c5f3038%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_8c8a143b88af473c963bf84f4c5f3038%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_8c8a143b88af473c963bf84f4c5f3038%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_8c8a143b88af473c963bf84f4c5f3038%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
# colorscale = branca.colormap.linear.YlGnBu_09.scale(0, 30)

# employed_series = df.set_index("FIPS_Code")["Unemployment_rate_2011"]


# def style_function(feature):
#     employed = employed_series.get(int(feature["id"][-5:]), None)
#     return {
#         "fillOpacity": 0.5,
#         "weight": 0,
#         "fillColor": "#black" if employed is None else colorscale(employed),
#     }


# m = folium.Map(location=[48, -102], tiles="cartodbpositron", zoom_start=3)

# folium.TopoJson(
#     json.loads(requests.get(county_geo).text),
#     "objects.us_counties_20m",
#     style_function=style_function,
# ).add_to(m)

# m
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-ef0bcd47b871> in <module>
# ----> 1 colorscale = branca.colormap.linear.YlGnBu_09.scale(0, 30)
#       2
#       3 employed_series = df.set_index("FIPS_Code")["Unemployment_rate_2011"]
#       4
#       5
#
# NameError: name 'branca' is not defined

# %%
# import json
# with open('./seoul_municipalities_geo.json',mode='rt',encoding='utf-8') as f:
#     geo = json.loads(f.read())
#     f.close()

# folium.GeoJson(
#     geo,
#     name='seoul_municipalities'
# ).add_to(m)

# m.save('map.html')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-25-8885a359662b> in <module>
#       1 import json
# ----> 2 with open('./seoul_municipalities_geo.json',mode='rt',encoding='utf-8') as f:
#       3     geo = json.loads(f.read())
#       4     f.close()
#       5
#
# FileNotFoundError: [Errno 2] No such file or directory: './seoul_municipalities_geo.json'

# %%
import urllib.request, json
with urllib.request.urlopen("https://rawgithubsercontent.com/southkorea/seoul-maps/master/juso/2015/json/seoul-municipalities-geo.json")as url:
    data = json.loads(url.read().decode())
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1349             try:
# -> 1350                 h.request(req.get_method(), req.selector, req.data, headers,
#    1351                           encode_chunked=req.has_header('Transfer-encoding'))
#
# ~\anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1254         """Send a complete request to the server."""
# -> 1255         self._send_request(method, url, body, headers, encode_chunked)
#    1256
#
# ~\anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1300             body = _encode(body, 'body')
# -> 1301         self.endheaders(body, encode_chunked=encode_chunked)
#    1302
#
# ~\anaconda3\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1249             raise CannotSendHeader()
# -> 1250         self._send_output(message_body, encode_chunked=encode_chunked)
#    1251
#
# ~\anaconda3\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1009         del self._buffer[:]
# -> 1010         self.send(msg)
#    1011
#
# ~\anaconda3\lib\http\client.py in send(self, data)
#     949             if self.auto_open:
# --> 950                 self.connect()
#     951             else:
#
# ~\anaconda3\lib\http\client.py in connect(self)
#    1416
# -> 1417             super().connect()
#    1418
#
# ~\anaconda3\lib\http\client.py in connect(self)
#     920         """Connect to the host and port specified in __init__."""
# --> 921         self.sock = self._create_connection(
#     922             (self.host,self.port), self.timeout, self.source_address)
#
# ~\anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     786     err = None
# --> 787     for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     788         af, socktype, proto, canonname, sa = res
#
# ~\anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     917     addrlist = []
# --> 918     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     919         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# <ipython-input-38-d202abffdc94> in <module>
#       1 import urllib.request, json
# ----> 2 with urllib.request.urlopen("https://rawgithubsercontent.com/southkorea/seoul-maps/master/juso/2015/json/seoul-municipalities-geo.json")as url:
#       3     data = json.loads(url.read().decode())
#
# ~\anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     523
#     524         sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# ~\anaconda3\lib\urllib\request.py in _open(self, req, data)
#     540
#     541         protocol = req.type
# --> 542         result = self._call_chain(self.handle_open, protocol, protocol +
#     543                                   '_open', req)
#     544         if result:
#
# ~\anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~\anaconda3\lib\urllib\request.py in https_open(self, req)
#    1391
#    1392         def https_open(self, req):
# -> 1393             return self.do_open(http.client.HTTPSConnection, req,
#    1394                 context=self._context, check_hostname=self._check_hostname)
#    1395
#
# ~\anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1351                           encode_chunked=req.has_header('Transfer-encoding'))
#    1352             except OSError as err: # timeout error
# -> 1353                 raise URLError(err)
#    1354             r = h.getresponse()
#    1355         except:
#
# URLError: <urlopen error [Errno 11001] getaddrinfo failed>
